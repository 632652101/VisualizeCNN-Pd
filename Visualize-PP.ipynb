# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
if __name__ == '__main__':
    import matplotlib.pyplot as plt
    import paddle
    from utils import apply_transforms, load_image

    image = load_image('content/images/great_grey_owl.jpg')

    from model.AlexNet import alexnet

    model = alexnet(True)
    model.eval()

    from saliency.backprop import Backprop

    backprop = Backprop(model)

    owl = apply_transforms(image)

    target_class = 24
    # Ready to roll!
    backprop.visualize(owl, target_class, guided=False, use_gpu=False)
# Out:
# /Users/mac/Downloads/github/Visualize-PP/saliency/backprop.py:62: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   target_np[0][top_class] = 1
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
peacock = apply_transforms(load_image('content/images/peacock.jpg'))
backprop.visualize(peacock, 84, guided=False, use_gpu=True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
